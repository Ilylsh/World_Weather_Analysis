# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np
# Import API key
import os
from dotenv import load_dotenv
load_dotenv()
weather_api_key = os.getenv("OpenWeather_API_KEY")
google_api_key = os.getenv("Google_API_KEY")

# Configure gmaps
gmaps.configure(api_key=google_api_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df
# Out:
#      City_ID         City Country  Max Temp Current Description      Lat  \
# 0          1        Bluff      NZ     60.64          few clouds -46.6000
# 1          3     Klaksvik      FO     45.52       broken clouds  62.2266
# 2          5        Kapaa      US     76.98     overcast clouds  22.0752
# 3          6  East London      ZA     70.74           clear sky -33.0153
# 4          7        Izumo      JP     53.55       broken clouds  35.3667
# ..       ...          ...     ...       ...                 ...      ...
# 346      696       Mehamn      NO     42.71     overcast clouds  71.0357
# 347      699    Algeciras      ES     58.68       broken clouds  36.1333
# 348      701    Elk Point      US     64.24     overcast clouds  42.6833
# 349      702  Hvide Sande      DK     41.09          light rain  56.0045
# 350      705     Bucerias      MX     67.98     overcast clouds  20.7500
#
#           Lng                                     Hotel Name
# 0    168.3333  Bluff Homestead - Guesthouse & Campervan Park
# 1     -6.5890                                   Airbnb rooms
# 2   -159.3190            Sheraton Kauai Coconut Beach Resort
# 3     27.9116                                        Tu Casa
# 4    132.7667                     Toyoko-Inn Izumoshi ekimae
# ..        ...                                            ...
# 346   27.8492                         Mehamn Arctic Hotel AS
# 347   -5.4505                 AC Hotel by Marriott Algeciras
# 348  -96.6836                                  Hometowne Inn
# 349    8.1294                              Hvide Sande Hotel
# 350 -105.3333      Royal Decameron Complex - Puerto Vallarta
#
# [351 rows x 8 columns]

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations,info_box_content = hotel_info)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_route = vacation_df.loc[(vacation_df['Country']=='US')]
vacation_route
# Out:
#      City_ID               City Country  Max Temp Current Description  \
# 2          5              Kapaa      US     76.98     overcast clouds
# 15        26             Bethel      US     45.93     overcast clouds
# 19        32              Sitka      US     42.69     overcast clouds
# 24        39             Laguna      US     55.69           clear sky
# 26        42             Lompoc      US     52.70                mist
# 31        57            Kahului      US     73.85       broken clouds
# 37        67            Lebanon      US     51.46       broken clouds
# 50        84       Rapid Valley      US     44.33           clear sky
# 63       110               Hilo      US     73.13       moderate rain
# 76       139  Wilmington Island      US     53.98           clear sky
# 80       144            Fortuna      US     43.72           clear sky
# 87       162       Stephenville      US     61.92    scattered clouds
# 88       165            Paducah      US     54.19           clear sky
# 110      223           Westport      US     46.62           clear sky
# 127      251       Saint George      US     48.94           clear sky
# 129      256            Ruidoso      US     48.96          few clouds
# 138      273      Makakilo City      US     74.28          light rain
# 144      283           Weymouth      US     45.48     overcast clouds
# 148      287           Griffith      US     49.89           clear sky
# 154      299         Morgantown      US     41.76           clear sky
# 159      310           Richland      US     40.19          few clouds
# 185      368           Portland      US     45.61          light rain
# 196      382            Hibbing      US     42.15          few clouds
# 201      394           Hamilton      US     50.31           clear sky
# 209      414           Freeport      US     47.25           clear sky
# 213      419       Port Hueneme      US     58.57           clear sky
# 215      423        Scottsbluff      US     53.83       broken clouds
# 242      489      Saint Anthony      US     52.97     overcast clouds
# 257      526    Madison Heights      US     43.05           clear sky
# 267      544   Lake Havasu City      US     66.81    scattered clouds
# 281      571            Pahrump      US     55.83           clear sky
# 287      585        Morgan City      US     53.60           clear sky
# 295      604      Pacific Grove      US     53.28           clear sky
# 305      623             Eureka      US     45.75     overcast clouds
# 319      649          Sylacauga      US     48.33     overcast clouds
# 329      662        Hattiesburg      US     49.44           clear sky
# 334      669           Ahuimanu      US     75.45          light rain
# 348      701          Elk Point      US     64.24     overcast clouds
#
#          Lat       Lng                                         Hotel Name
# 2    22.0752 -159.3190                Sheraton Kauai Coconut Beach Resort
# 15   41.3712  -73.4140                      Courtyard by Marriott Danbury
# 19   57.0531 -135.3300                                     Westmark Sitka
# 24   38.4210 -121.4238  Holiday Inn Express & Suites Elk Grove Central...
# 26   34.6391 -120.4579           Holiday Inn Express Lompoc, an IHG Hotel
# 31   20.8947 -156.4700                                 Maui Seaside Hotel
# 37   36.2081  -86.2911                       Hampton Inn & Suites Lebanon
# 50   44.0625 -103.1463      Fairfield Inn & Suites by Marriott Rapid City
# 63   19.7297 -155.0900                                Hilo Hawaiian Hotel
# 76   32.0036  -80.9737                         Breezeway Studio Manor LLC
# 80   40.5982 -124.1573                         Super 8 by Wyndham Fortuna
# 87   32.2207  -98.2023     La Quinta Inn & Suites by Wyndham Stephenville
# 88   37.0834  -88.6001       Holiday Inn Paducah Riverfront, an IHG Hotel
# 110  41.1415  -73.3579                               The Inn at Longshore
# 127  37.1041 -113.5841                        Best Western Plus Abbey Inn
# 129  33.3317 -105.6730                           Inn of the Mountain Gods
# 138  21.3469 -158.0858                     Marriott's Ko Olina Beach Club
# 144  42.2209  -70.9398                              Arbor Inn Motor Lodge
# 148  41.5284  -87.4237                          Apartment above Depot Bar
# 154  39.6295  -79.9559            Morgantown Marriott at Waterfront Place
# 159  40.7834  -82.5499                      Hampton Inn Mansfield/Ontario
# 185  45.5234 -122.6762         Embassy Suites by Hilton Portland Downtown
# 196  47.4272  -92.9377                    Americas Best Value Inn Hibbing
# 201  39.1834  -84.5333                          Six Acres Bed & Breakfast
# 209  40.6576  -73.5832                        The Freeport Inn and Marina
# 213  34.1478 -119.1951                 Hampton Inn Channel Islands Harbor
# 215  41.8666 -103.6672  Hampton Inn & Suites Scottsbluff-Conference Ce...
# 242  45.0205  -93.2180  Holiday Inn Express Roseville-St. Paul, an IHG...
# 257  42.4859  -83.1052                      Red Roof Inn Detroit - Warren
# 267  34.4839 -114.3224                                         Heat Hotel
# 281  36.2083 -115.9839                         Best Western Pahrump Oasis
# 287  29.6994  -91.2068                   Hampton Inn & Suites Morgan City
# 295  36.6177 -121.9166                                   Lovers Point Inn
# 305  40.8021 -124.1637                    Eureka Inn Trademark By Wyndham
# 319  33.1732  -86.2516  Holiday Inn Express & Suites Sylacauga, an IHG...
# 329  31.3271  -89.2903                                         Deluxe Inn
# 334  21.4447 -157.8378                                Paradise Bay Resort
# 348  42.6833  -96.6836                                      Hometowne Inn

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.
vacation_start = vacation_df.loc[vacation_df['City']=='Portland']
vacation_end = vacation_df.loc[vacation_df['City']=='Portland']
vacation_stop1 = vacation_df.loc[vacation_df['City']=='Morgan City']
vacation_stop2 = vacation_df.loc[vacation_df['City']=='Lake Havasu City'] 
vacation_stop3 = vacation_df.loc[vacation_df['City']=='Fortuna']

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0]
print(f'Start: {start}, End: {end}')

stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]
print(f'Stop 1: {stop1}, Stop 2: {stop2},Stop 3: {stop3}')
# Out:
# Start: (45.5234, -122.6762), End: (45.5234, -122.6762)
# Stop 1: (29.6994, -91.2068), Stop 2: (34.4839, -114.3224),Stop 3: (40.5982, -124.1573)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
city_itinerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2,stop3],
        travel_mode='DRIVING')

# %%
# 8. To create a marker layer map between the four cities.
fig.add_layer(city_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID              City Country  Max Temp Current Description      Lat  \
# 0      368          Portland      US     45.61          light rain  45.5234
# 1      585       Morgan City      US     53.60           clear sky  29.6994
# 2      544  Lake Havasu City      US     66.81    scattered clouds  34.4839
# 3      144           Fortuna      US     43.72           clear sky  40.5982
#
#         Lng                                  Hotel Name
# 0 -122.6762  Embassy Suites by Hilton Portland Downtown
# 1  -91.2068            Hampton Inn & Suites Morgan City
# 2 -114.3224                                  Heat Hotel
# 3 -124.1573                  Super 8 by Wyndham Fortuna

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations,info_box_content = hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
