# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import os
from dotenv import load_dotenv
load_dotenv()
weather_api_key = os.getenv("OpenWeather_API_KEY")
google_api_key = os.getenv("Google_API_KEY")
# Import the time library and the datetime module from the datetime library 
import time 
from datetime import datetime
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 764

# %%
city_data = []
url = "http://api.openweathermap.org/data/2.5/weather?APPID=" + weather_api_key
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+") + "&units=imperial"

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | talnakh
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | beloha
# Processing Record 4 of Set 1 | klaksvik
# Processing Record 5 of Set 1 | nanortalik
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | izumo
# Processing Record 11 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 1 | alofi
# Processing Record 13 of Set 1 | monkey bay
# Processing Record 14 of Set 1 | bengkulu
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | tiksi
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | kalispell
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | matay
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | hambantota
# Processing Record 24 of Set 1 | andenes
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | wanxian
# Processing Record 27 of Set 1 | beitbridge
# Processing Record 28 of Set 1 | kirakira
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | severo-kurilsk
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | akdepe
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | dunedin
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | sitka
# Processing Record 39 of Set 1 | hun
# Processing Record 40 of Set 1 | zhezkazgan
# Processing Record 41 of Set 1 | tumut
# Processing Record 42 of Set 1 | geraldton
# Processing Record 43 of Set 1 | tricase
# Processing Record 44 of Set 1 | chuy
# Processing Record 45 of Set 1 | laguna
# Processing Record 46 of Set 1 | maceio
# Processing Record 47 of Set 1 | sungairaya
# Processing Record 48 of Set 1 | lompoc
# Processing Record 49 of Set 1 | srandakan
# Processing Record 50 of Set 1 | cuamba
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | udachnyy
# Processing Record 3 of Set 2 | xichang
# Processing Record 4 of Set 2 | kutum
# Processing Record 5 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | khabary
# Processing Record 9 of Set 2 | kabinda
# Processing Record 10 of Set 2 | nikolskoye
# Processing Record 11 of Set 2 | lodwar
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | dingle
# Processing Record 14 of Set 2 | kahului
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | saint-philippe
# Processing Record 17 of Set 2 | torbay
# Processing Record 18 of Set 2 | masallatah
# Processing Record 19 of Set 2 | port elizabeth
# Processing Record 20 of Set 2 | sinnamary
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | mapulot
# Processing Record 24 of Set 2 | ilovlya
# Processing Record 25 of Set 2 | lebanon
# Processing Record 26 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 2 | bubaque
# Processing Record 28 of Set 2 | college
# Processing Record 29 of Set 2 | saint-joseph
# Processing Record 30 of Set 2 | ribeira grande
# Processing Record 31 of Set 2 | ryotsu
# Processing Record 32 of Set 2 | bani
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | namibe
# Processing Record 36 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | souillac
# Processing Record 39 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 40 of Set 2 | khatanga
# Processing Record 41 of Set 2 | iquitos
# Processing Record 42 of Set 2 | umm lajj
# Processing Record 43 of Set 2 | marienburg
# Processing Record 44 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 45 of Set 2 | bastos
# Processing Record 46 of Set 2 | rapid valley
# Processing Record 47 of Set 2 | sola
# Processing Record 48 of Set 2 | saldanha
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 50 of Set 2 | sao joao da barra
# Processing Record 1 of Set 3 | punta arenas
# Processing Record 2 of Set 3 | hithadhoo
# Processing Record 3 of Set 3 | longyearbyen
# Processing Record 4 of Set 3 | along
# Processing Record 5 of Set 3 | sao filipe
# Processing Record 6 of Set 3 | komsomolskiy
# Processing Record 7 of Set 3 | caravelas
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | buraydah
# Processing Record 10 of Set 3 | bairiki
# Processing Record 11 of Set 3 | iqaluit
# Processing Record 12 of Set 3 | labuhan
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | paamiut
# Processing Record 16 of Set 3 | gonen
# Processing Record 17 of Set 3 | carmarthen
# Processing Record 18 of Set 3 | fort nelson
# Processing Record 19 of Set 3 | muros
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | pevek
# Processing Record 23 of Set 3 | hilo
# Processing Record 24 of Set 3 | chingirlau
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | teguise
# Processing Record 27 of Set 3 | pokotylivka
# Processing Record 28 of Set 3 | naze
# Processing Record 29 of Set 3 | broome
# Processing Record 30 of Set 3 | hermanus
# Processing Record 31 of Set 3 | qaanaaq
# Processing Record 32 of Set 3 | zhengjiatun
# Processing Record 33 of Set 3 | beringovskiy
# Processing Record 34 of Set 3 | ponta do sol
# Processing Record 35 of Set 3 | yelizovo
# Processing Record 36 of Set 3 | chicama
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | cootamundra
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | tabulbah
# City not found. Skipping...
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | new norfolk
# Processing Record 43 of Set 3 | iquique
# Processing Record 44 of Set 3 | ambulu
# Processing Record 45 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 3 | norman wells
# Processing Record 47 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 3 | taga
# Processing Record 49 of Set 3 | hami
# Processing Record 50 of Set 3 | kendari
# Processing Record 1 of Set 4 | praia da vitoria
# Processing Record 2 of Set 4 | znamenskoye
# Processing Record 3 of Set 4 | port hardy
# Processing Record 4 of Set 4 | bonavista
# Processing Record 5 of Set 4 | wilmington island
# Processing Record 6 of Set 4 | hatillo
# Processing Record 7 of Set 4 | umm kaddadah
# Processing Record 8 of Set 4 | bonthe
# Processing Record 9 of Set 4 | hualmay
# Processing Record 10 of Set 4 | fortuna
# Processing Record 11 of Set 4 | tucuman
# Processing Record 12 of Set 4 | hervey bay
# Processing Record 13 of Set 4 | kattivakkam
# Processing Record 14 of Set 4 | upernavik
# Processing Record 15 of Set 4 | tiznit
# Processing Record 16 of Set 4 | faanui
# Processing Record 17 of Set 4 | carnarvon
# Processing Record 18 of Set 4 | sisimiut
# Processing Record 19 of Set 4 | tromso
# Processing Record 20 of Set 4 | requena
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | airai
# Processing Record 23 of Set 4 | svetlogorsk
# Processing Record 24 of Set 4 | mount isa
# Processing Record 25 of Set 4 | kodiak
# Processing Record 26 of Set 4 | thohoyandou
# Processing Record 27 of Set 4 | cayenne
# Processing Record 28 of Set 4 | stephenville
# Processing Record 29 of Set 4 | palana
# Processing Record 30 of Set 4 | kungurtug
# Processing Record 31 of Set 4 | paducah
# Processing Record 32 of Set 4 | litoral del san juan
# City not found. Skipping...
# Processing Record 33 of Set 4 | bulaevo
# Processing Record 34 of Set 4 | khandagayty
# Processing Record 35 of Set 4 | deputatskiy
# Processing Record 36 of Set 4 | mudanjiang
# Processing Record 37 of Set 4 | robe
# Processing Record 38 of Set 4 | yuksekova
# Processing Record 39 of Set 4 | gimbi
# Processing Record 40 of Set 4 | basco
# Processing Record 41 of Set 4 | lagoa
# Processing Record 42 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 4 | shkotovo-22
# City not found. Skipping...
# Processing Record 44 of Set 4 | lebu
# Processing Record 45 of Set 4 | leningradskiy
# Processing Record 46 of Set 4 | avarua
# Processing Record 47 of Set 4 | mwinilunga
# Processing Record 48 of Set 4 | mattru
# Processing Record 49 of Set 4 | rawson
# Processing Record 50 of Set 4 | vaini
# Processing Record 1 of Set 5 | hobyo
# Processing Record 2 of Set 5 | pisco
# Processing Record 3 of Set 5 | wajir
# Processing Record 4 of Set 5 | safaga
# Processing Record 5 of Set 5 | ayagoz
# Processing Record 6 of Set 5 | basoko
# Processing Record 7 of Set 5 | alamosa
# Processing Record 8 of Set 5 | bartica
# Processing Record 9 of Set 5 | anadyr
# Processing Record 10 of Set 5 | katherine
# Processing Record 11 of Set 5 | eskisehir
# Processing Record 12 of Set 5 | berdigestyakh
# Processing Record 13 of Set 5 | muroto
# Processing Record 14 of Set 5 | kologriv
# Processing Record 15 of Set 5 | yulara
# Processing Record 16 of Set 5 | leh
# Processing Record 17 of Set 5 | chokurdakh
# Processing Record 18 of Set 5 | aketi
# Processing Record 19 of Set 5 | aranos
# Processing Record 20 of Set 5 | katsuura
# Processing Record 21 of Set 5 | pryamitsyno
# Processing Record 22 of Set 5 | staszow
# Processing Record 23 of Set 5 | tambovka
# Processing Record 24 of Set 5 | kimberley
# Processing Record 25 of Set 5 | rexburg
# Processing Record 26 of Set 5 | borsec
# Processing Record 27 of Set 5 | roebourne
# Processing Record 28 of Set 5 | okhotsk
# Processing Record 29 of Set 5 | nizwa
# Processing Record 30 of Set 5 | tuatapere
# Processing Record 31 of Set 5 | cherskiy
# Processing Record 32 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 5 | sorland
# Processing Record 34 of Set 5 | agua blanca
# Processing Record 35 of Set 5 | victoria
# Processing Record 36 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 37 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 5 | srednekolymsk
# Processing Record 39 of Set 5 | sibu
# Processing Record 40 of Set 5 | tuktoyaktuk
# Processing Record 41 of Set 5 | nuuk
# Processing Record 42 of Set 5 | axim
# Processing Record 43 of Set 5 | uray
# Processing Record 44 of Set 5 | antofagasta
# Processing Record 45 of Set 5 | westport
# Processing Record 46 of Set 5 | kaeo
# Processing Record 47 of Set 5 | waingapu
# Processing Record 48 of Set 5 | sibolga
# Processing Record 49 of Set 5 | trairi
# Processing Record 50 of Set 5 | sioux lookout
# Processing Record 1 of Set 6 | najran
# Processing Record 2 of Set 6 | acarau
# Processing Record 3 of Set 6 | dilla
# Processing Record 4 of Set 6 | baijiantan
# Processing Record 5 of Set 6 | vao
# Processing Record 6 of Set 6 | karpathos
# Processing Record 7 of Set 6 | kruisfontein
# Processing Record 8 of Set 6 | broken hill
# Processing Record 9 of Set 6 | nishihara
# Processing Record 10 of Set 6 | shenjiamen
# Processing Record 11 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 6 | santa rosa
# Processing Record 13 of Set 6 | san isidro
# Processing Record 14 of Set 6 | chinsali
# Processing Record 15 of Set 6 | alekseyevsk
# Processing Record 16 of Set 6 | ulladulla
# Processing Record 17 of Set 6 | chapais
# Processing Record 18 of Set 6 | snezhnogorsk
# Processing Record 19 of Set 6 | ciudad bolivar
# Processing Record 20 of Set 6 | bambous virieux
# Processing Record 21 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 6 | chulman
# Processing Record 23 of Set 6 | codrington
# Processing Record 24 of Set 6 | hasaki
# Processing Record 25 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 6 | saint george
# Processing Record 27 of Set 6 | matamoros
# Processing Record 28 of Set 6 | kukuna
# Processing Record 29 of Set 6 | sur
# Processing Record 30 of Set 6 | antropovo
# Processing Record 31 of Set 6 | ruidoso
# Processing Record 32 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 6 | lokoja
# Processing Record 34 of Set 6 | mogadishu
# Processing Record 35 of Set 6 | gamba
# Processing Record 36 of Set 6 | montepuez
# Processing Record 37 of Set 6 | manggar
# Processing Record 38 of Set 6 | coquimbo
# Processing Record 39 of Set 6 | te anau
# Processing Record 40 of Set 6 | magaria
# Processing Record 41 of Set 6 | general pico
# Processing Record 42 of Set 6 | ban tak
# Processing Record 43 of Set 6 | albina
# Processing Record 44 of Set 6 | drovyanaya
# Processing Record 45 of Set 6 | tomatlan
# Processing Record 46 of Set 6 | tazovskiy
# Processing Record 47 of Set 6 | urumqi
# Processing Record 48 of Set 6 | ucluelet
# Processing Record 49 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 6 | makakilo city
# Processing Record 1 of Set 7 | poum
# Processing Record 2 of Set 7 | isla mujeres
# Processing Record 3 of Set 7 | dengzhou
# Processing Record 4 of Set 7 | puerto del rosario
# Processing Record 5 of Set 7 | yumen
# Processing Record 6 of Set 7 | kenora
# Processing Record 7 of Set 7 | ribeira brava
# Processing Record 8 of Set 7 | cairns
# Processing Record 9 of Set 7 | chodziez
# Processing Record 10 of Set 7 | weymouth
# Processing Record 11 of Set 7 | guerrero negro
# Processing Record 12 of Set 7 | farafangana
# Processing Record 13 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 7 | miyazu
# Processing Record 15 of Set 7 | griffith
# Processing Record 16 of Set 7 | tautira
# Processing Record 17 of Set 7 | alta floresta
# Processing Record 18 of Set 7 | tahta
# Processing Record 19 of Set 7 | opuwo
# Processing Record 20 of Set 7 | vestmanna
# Processing Record 21 of Set 7 | husavik
# Processing Record 22 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 7 | merauke
# Processing Record 24 of Set 7 | chameza
# City not found. Skipping...
# Processing Record 25 of Set 7 | dalaba
# Processing Record 26 of Set 7 | dire
# Processing Record 27 of Set 7 | maun
# Processing Record 28 of Set 7 | ilulissat
# Processing Record 29 of Set 7 | morgantown
# Processing Record 30 of Set 7 | namatanai
# Processing Record 31 of Set 7 | verkhoyansk
# Processing Record 32 of Set 7 | marsh harbour
# Processing Record 33 of Set 7 | dandong
# Processing Record 34 of Set 7 | jacareacanga
# Processing Record 35 of Set 7 | thessalon
# Processing Record 36 of Set 7 | tumaco
# Processing Record 37 of Set 7 | clyde river
# Processing Record 38 of Set 7 | inhambane
# Processing Record 39 of Set 7 | barrow
# Processing Record 40 of Set 7 | richland
# Processing Record 41 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 7 | urk
# Processing Record 43 of Set 7 | francisco sa
# Processing Record 44 of Set 7 | kloulklubed
# Processing Record 45 of Set 7 | tottori
# Processing Record 46 of Set 7 | lucea
# Processing Record 47 of Set 7 | tsuyama
# Processing Record 48 of Set 7 | biltine
# Processing Record 49 of Set 7 | saint-pierre
# Processing Record 50 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 1 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 8 | wanaka
# Processing Record 3 of Set 8 | tayga
# Processing Record 4 of Set 8 | ambilobe
# Processing Record 5 of Set 8 | salinopolis
# Processing Record 6 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 7 of Set 8 | krasnaya gora
# Processing Record 8 of Set 8 | olinda
# Processing Record 9 of Set 8 | soyo
# Processing Record 10 of Set 8 | sistranda
# Processing Record 11 of Set 8 | saint-francois
# Processing Record 12 of Set 8 | kaabong
# Processing Record 13 of Set 8 | aksehir
# Processing Record 14 of Set 8 | rajmahal
# Processing Record 15 of Set 8 | tayoltita
# Processing Record 16 of Set 8 | vardo
# Processing Record 17 of Set 8 | mari-turek
# Processing Record 18 of Set 8 | grindavik
# Processing Record 19 of Set 8 | olafsvik
# Processing Record 20 of Set 8 | vila
# Processing Record 21 of Set 8 | agas
# Processing Record 22 of Set 8 | delta del tigre
# Processing Record 23 of Set 8 | makaryev
# Processing Record 24 of Set 8 | kemise
# Processing Record 25 of Set 8 | faya
# Processing Record 26 of Set 8 | palanga
# Processing Record 27 of Set 8 | san andres
# Processing Record 28 of Set 8 | henties bay
# Processing Record 29 of Set 8 | peachland
# Processing Record 30 of Set 8 | kharp
# Processing Record 31 of Set 8 | tilichiki
# Processing Record 32 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 8 | kavaratti
# Processing Record 34 of Set 8 | jumla
# Processing Record 35 of Set 8 | lerwick
# Processing Record 36 of Set 8 | kyaikto
# Processing Record 37 of Set 8 | nemuro
# Processing Record 38 of Set 8 | kulhudhuffushi
# Processing Record 39 of Set 8 | brae
# Processing Record 40 of Set 8 | kiunga
# Processing Record 41 of Set 8 | miri
# Processing Record 42 of Set 8 | west wendover
# Processing Record 43 of Set 8 | bandar-e lengeh
# Processing Record 44 of Set 8 | richards bay
# Processing Record 45 of Set 8 | stebnyk
# Processing Record 46 of Set 8 | kindu
# Processing Record 47 of Set 8 | roma
# Processing Record 48 of Set 8 | kota belud
# Processing Record 49 of Set 8 | chak
# Processing Record 50 of Set 8 | pionerskiy
# Processing Record 1 of Set 9 | oktyabrskiy
# Processing Record 2 of Set 9 | yining
# Processing Record 3 of Set 9 | portland
# Processing Record 4 of Set 9 | gold coast
# Processing Record 5 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 9 | otradnoye
# Processing Record 7 of Set 9 | garissa
# Processing Record 8 of Set 9 | semirom
# Processing Record 9 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 10 of Set 9 | barcelos
# Processing Record 11 of Set 9 | biak
# Processing Record 12 of Set 9 | kemijarvi
# Processing Record 13 of Set 9 | svetlyy
# Processing Record 14 of Set 9 | sechura
# Processing Record 15 of Set 9 | ixtapa
# Processing Record 16 of Set 9 | mercedes
# Processing Record 17 of Set 9 | luanda
# Processing Record 18 of Set 9 | shakiso
# Processing Record 19 of Set 9 | hibbing
# Processing Record 20 of Set 9 | magadan
# Processing Record 21 of Set 9 | zyryanka
# Processing Record 22 of Set 9 | fenoarivo
# Processing Record 23 of Set 9 | grand-lahou
# Processing Record 24 of Set 9 | oranjemund
# Processing Record 25 of Set 9 | tawang
# Processing Record 26 of Set 9 | petrivka
# Processing Record 27 of Set 9 | turan
# Processing Record 28 of Set 9 | haines junction
# Processing Record 29 of Set 9 | sartana
# Processing Record 30 of Set 9 | iskateley
# Processing Record 31 of Set 9 | hamilton
# Processing Record 32 of Set 9 | aksarka
# Processing Record 33 of Set 9 | pangnirtung
# Processing Record 34 of Set 9 | salalah
# Processing Record 35 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 9 | bay roberts
# Processing Record 37 of Set 9 | marzuq
# Processing Record 38 of Set 9 | maumere
# Processing Record 39 of Set 9 | faratsiho
# Processing Record 40 of Set 9 | lysyanka
# Processing Record 41 of Set 9 | severo-yeniseyskiy
# Processing Record 42 of Set 9 | zhanaozen
# Processing Record 43 of Set 9 | xicotencatl
# Processing Record 44 of Set 9 | iguape
# Processing Record 45 of Set 9 | rio cuarto
# Processing Record 46 of Set 9 | zhizdra
# Processing Record 47 of Set 9 | naliya
# Processing Record 48 of Set 9 | santa cruz do rio pardo
# Processing Record 49 of Set 9 | ourossogui
# Processing Record 50 of Set 9 | anzio
# Processing Record 1 of Set 10 | nizhniy chir
# Processing Record 2 of Set 10 | freeport
# Processing Record 3 of Set 10 | lorengau
# Processing Record 4 of Set 10 | carmen
# Processing Record 5 of Set 10 | constitucion
# Processing Record 6 of Set 10 | chimore
# Processing Record 7 of Set 10 | port hueneme
# Processing Record 8 of Set 10 | amuntai
# Processing Record 9 of Set 10 | bambanglipuro
# Processing Record 10 of Set 10 | hokitika
# Processing Record 11 of Set 10 | scottsbluff
# Processing Record 12 of Set 10 | mandera
# Processing Record 13 of Set 10 | warrington
# Processing Record 14 of Set 10 | huarmey
# Processing Record 15 of Set 10 | paoua
# Processing Record 16 of Set 10 | qaqortoq
# Processing Record 17 of Set 10 | mazinde
# Processing Record 18 of Set 10 | embonas
# Processing Record 19 of Set 10 | rocha
# Processing Record 20 of Set 10 | yuanping
# Processing Record 21 of Set 10 | kirando
# Processing Record 22 of Set 10 | bilibino
# Processing Record 23 of Set 10 | babu
# Processing Record 24 of Set 10 | muzhi
# Processing Record 25 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 10 | idrinskoye
# Processing Record 27 of Set 10 | port macquarie
# Processing Record 28 of Set 10 | ambon
# Processing Record 29 of Set 10 | heze
# Processing Record 30 of Set 10 | pimentel
# Processing Record 31 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 10 | milkovo
# Processing Record 33 of Set 10 | ulaangom
# Processing Record 34 of Set 10 | urdoma
# Processing Record 35 of Set 10 | angol
# Processing Record 36 of Set 10 | dudinka
# Processing Record 37 of Set 10 | zapote
# Processing Record 38 of Set 10 | la ronge
# Processing Record 39 of Set 10 | zhaotong
# Processing Record 40 of Set 10 | togur
# Processing Record 41 of Set 10 | kuytun
# Processing Record 42 of Set 10 | tura
# Processing Record 43 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 10 | ludvika
# Processing Record 45 of Set 10 | buta
# Processing Record 46 of Set 10 | san policarpo
# Processing Record 47 of Set 10 | kahramanmaras
# Processing Record 48 of Set 10 | santa isabel do rio negro
# Processing Record 49 of Set 10 | mpongwe
# Processing Record 50 of Set 10 | mega
# Processing Record 1 of Set 11 | batagay
# Processing Record 2 of Set 11 | vanimo
# Processing Record 3 of Set 11 | meiktila
# Processing Record 4 of Set 11 | sobolevo
# Processing Record 5 of Set 11 | raudeberg
# Processing Record 6 of Set 11 | porto novo
# Processing Record 7 of Set 11 | ancud
# Processing Record 8 of Set 11 | saint-augustin
# Processing Record 9 of Set 11 | behshahr
# Processing Record 10 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 11 | matagami
# Processing Record 12 of Set 11 | aykhal
# Processing Record 13 of Set 11 | stornoway
# Processing Record 14 of Set 11 | weinan
# Processing Record 15 of Set 11 | riyadh
# Processing Record 16 of Set 11 | bergerac
# Processing Record 17 of Set 11 | bara
# Processing Record 18 of Set 11 | cap malheureux
# Processing Record 19 of Set 11 | les cayes
# Processing Record 20 of Set 11 | tibu
# Processing Record 21 of Set 11 | port lincoln
# Processing Record 22 of Set 11 | tessalit
# Processing Record 23 of Set 11 | kachug
# Processing Record 24 of Set 11 | vila franca do campo
# Processing Record 25 of Set 11 | ouegoa
# Processing Record 26 of Set 11 | carbonia
# Processing Record 27 of Set 11 | kyra
# Processing Record 28 of Set 11 | juripiranga
# Processing Record 29 of Set 11 | maniitsoq
# Processing Record 30 of Set 11 | saint anthony
# Processing Record 31 of Set 11 | kysyl-syr
# Processing Record 32 of Set 11 | kibala
# Processing Record 33 of Set 11 | teya
# Processing Record 34 of Set 11 | muscat
# Processing Record 35 of Set 11 | skibotn
# Processing Record 36 of Set 11 | shache
# Processing Record 37 of Set 11 | ajdabiya
# Processing Record 38 of Set 11 | sinazongwe
# Processing Record 39 of Set 11 | bongandanga
# Processing Record 40 of Set 11 | vostok
# Processing Record 41 of Set 11 | myitkyina
# Processing Record 42 of Set 11 | lahad datu
# Processing Record 43 of Set 11 | vidim
# Processing Record 44 of Set 11 | mukhen
# Processing Record 45 of Set 11 | almaznyy
# Processing Record 46 of Set 11 | kotelnikovo
# Processing Record 47 of Set 11 | voyvozh
# Processing Record 48 of Set 11 | bathsheba
# Processing Record 49 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 50 of Set 11 | khanpur
# Processing Record 1 of Set 12 | iralaya
# Processing Record 2 of Set 12 | lafiagi
# Processing Record 3 of Set 12 | fare
# Processing Record 4 of Set 12 | port keats
# Processing Record 5 of Set 12 | khawhai
# Processing Record 6 of Set 12 | podor
# Processing Record 7 of Set 12 | san vicente
# Processing Record 8 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 12 | macherla
# Processing Record 10 of Set 12 | benguela
# Processing Record 11 of Set 12 | jos
# Processing Record 12 of Set 12 | anito
# Processing Record 13 of Set 12 | karangasem
# Processing Record 14 of Set 12 | havoysund
# Processing Record 15 of Set 12 | touros
# Processing Record 16 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 17 of Set 12 | lata
# Processing Record 18 of Set 12 | santiago
# Processing Record 19 of Set 12 | zabaykalsk
# Processing Record 20 of Set 12 | madison heights
# Processing Record 21 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 22 of Set 12 | bonfim
# Processing Record 23 of Set 12 | mianwali
# Processing Record 24 of Set 12 | hofn
# Processing Record 25 of Set 12 | gat
# Processing Record 26 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 12 | buala
# Processing Record 28 of Set 12 | gao
# Processing Record 29 of Set 12 | burns lake
# Processing Record 30 of Set 12 | yangambi
# Processing Record 31 of Set 12 | sawakin
# Processing Record 32 of Set 12 | coahuayana
# Processing Record 33 of Set 12 | surgut
# Processing Record 34 of Set 12 | shakawe
# Processing Record 35 of Set 12 | koscierzyna
# Processing Record 36 of Set 12 | kupino
# Processing Record 37 of Set 12 | el tigre
# Processing Record 38 of Set 12 | owando
# Processing Record 39 of Set 12 | vila velha
# Processing Record 40 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 12 | lake havasu city
# Processing Record 42 of Set 12 | tygda
# Processing Record 43 of Set 12 | mount gambier
# Processing Record 44 of Set 12 | cockburn town
# Processing Record 45 of Set 12 | puerto escondido
# Processing Record 46 of Set 12 | khash
# Processing Record 47 of Set 12 | saravan
# Processing Record 48 of Set 12 | wuda
# Processing Record 49 of Set 12 | batagay-alyta
# Processing Record 50 of Set 12 | prince rupert
# Processing Record 1 of Set 13 | nichinan
# Processing Record 2 of Set 13 | goderich
# Processing Record 3 of Set 13 | igarape-miri
# City not found. Skipping...
# Processing Record 4 of Set 13 | havre-saint-pierre
# Processing Record 5 of Set 13 | caxito
# Processing Record 6 of Set 13 | betsiamites
# Processing Record 7 of Set 13 | marawi
# Processing Record 8 of Set 13 | samarai
# Processing Record 9 of Set 13 | asau
# Processing Record 10 of Set 13 | graaff-reinet
# Processing Record 11 of Set 13 | kasaoka
# Processing Record 12 of Set 13 | magdagachi
# Processing Record 13 of Set 13 | akyab
# Processing Record 14 of Set 13 | lavrentiya
# Processing Record 15 of Set 13 | luau
# Processing Record 16 of Set 13 | esperance
# Processing Record 17 of Set 13 | ipixuna
# Processing Record 18 of Set 13 | deogarh
# Processing Record 19 of Set 13 | pahrump
# Processing Record 20 of Set 13 | tarauaca
# Processing Record 21 of Set 13 | shieli
# Processing Record 22 of Set 13 | buchanan
# Processing Record 23 of Set 13 | bahia honda
# Processing Record 24 of Set 13 | novoplatnirovskaya
# Processing Record 25 of Set 13 | gizo
# Processing Record 26 of Set 13 | bulgan
# Processing Record 27 of Set 13 | xining
# Processing Record 28 of Set 13 | gazojak
# Processing Record 29 of Set 13 | luderitz
# Processing Record 30 of Set 13 | synya
# Processing Record 31 of Set 13 | belaya gora
# Processing Record 32 of Set 13 | wakkanai
# Processing Record 33 of Set 13 | morgan city
# Processing Record 34 of Set 13 | suntar
# Processing Record 35 of Set 13 | bridlington
# Processing Record 36 of Set 13 | carballo
# Processing Record 37 of Set 13 | yerbogachen
# Processing Record 38 of Set 13 | isangel
# Processing Record 39 of Set 13 | cabra
# Processing Record 40 of Set 13 | donskoye
# Processing Record 41 of Set 13 | abomsa
# Processing Record 42 of Set 13 | shahreza
# Processing Record 43 of Set 13 | hauterive
# Processing Record 44 of Set 13 | katesh
# Processing Record 45 of Set 13 | kilindoni
# Processing Record 46 of Set 13 | nome
# Processing Record 47 of Set 13 | roi et
# Processing Record 48 of Set 13 | farafenni
# Processing Record 49 of Set 13 | narbonne
# Processing Record 50 of Set 13 | khovu-aksy
# Processing Record 1 of Set 14 | agadez
# Processing Record 2 of Set 14 | pacific grove
# Processing Record 3 of Set 14 | moerai
# Processing Record 4 of Set 14 | guatire
# Processing Record 5 of Set 14 | boa vista
# Processing Record 6 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 7 of Set 14 | rosa zarate
# Processing Record 8 of Set 14 | fairbanks
# Processing Record 9 of Set 14 | partizanskoye
# Processing Record 10 of Set 14 | bafra
# Processing Record 11 of Set 14 | bouillante
# Processing Record 12 of Set 14 | manaus
# Processing Record 13 of Set 14 | caruray
# Processing Record 14 of Set 14 | araouane
# Processing Record 15 of Set 14 | adrar
# Processing Record 16 of Set 14 | marsaxlokk
# Processing Record 17 of Set 14 | gigmoto
# Processing Record 18 of Set 14 | santa lucia
# Processing Record 19 of Set 14 | rancho veloz
# Processing Record 20 of Set 14 | de haan
# Processing Record 21 of Set 14 | comodoro rivadavia
# Processing Record 22 of Set 14 | eureka
# Processing Record 23 of Set 14 | nieuw nickerie
# Processing Record 24 of Set 14 | narsaq
# Processing Record 25 of Set 14 | chastyye
# Processing Record 26 of Set 14 | adre
# Processing Record 27 of Set 14 | vrangel
# Processing Record 28 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 29 of Set 14 | aksu
# Processing Record 30 of Set 14 | temir
# Processing Record 31 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 32 of Set 14 | kokemaki
# Processing Record 33 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 14 | pulandian
# Processing Record 35 of Set 14 | manavalakurichi
# Processing Record 36 of Set 14 | morden
# Processing Record 37 of Set 14 | seoul
# Processing Record 38 of Set 14 | honiara
# Processing Record 39 of Set 14 | tanjong sepat
# City not found. Skipping...
# Processing Record 40 of Set 14 | pokhara
# Processing Record 41 of Set 14 | kuzino
# Processing Record 42 of Set 14 | roald
# Processing Record 43 of Set 14 | birjand
# Processing Record 44 of Set 14 | lianran
# Processing Record 45 of Set 14 | renigunta
# Processing Record 46 of Set 14 | benghazi
# Processing Record 47 of Set 14 | trezzano sul naviglio
# Processing Record 48 of Set 14 | santa cruz cabralia
# Processing Record 49 of Set 14 | asfi
# Processing Record 50 of Set 14 | pyaozerskiy
# Processing Record 1 of Set 15 | el fuerte
# Processing Record 2 of Set 15 | sylacauga
# Processing Record 3 of Set 15 | port blair
# Processing Record 4 of Set 15 | ormara
# Processing Record 5 of Set 15 | gravdal
# Processing Record 6 of Set 15 | san rafael
# Processing Record 7 of Set 15 | coihaique
# Processing Record 8 of Set 15 | kushima
# Processing Record 9 of Set 15 | teahupoo
# Processing Record 10 of Set 15 | rudnogorsk
# Processing Record 11 of Set 15 | goroka
# Processing Record 12 of Set 15 | labrea
# Processing Record 13 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 14 of Set 15 | lelystad
# Processing Record 15 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 16 of Set 15 | dovolnoye
# Processing Record 17 of Set 15 | hattiesburg
# Processing Record 18 of Set 15 | port arthur
# Processing Record 19 of Set 15 | ahipara
# Processing Record 20 of Set 15 | noumea
# Processing Record 21 of Set 15 | colquechaca
# Processing Record 22 of Set 15 | waipawa
# Processing Record 23 of Set 15 | marsabit
# Processing Record 24 of Set 15 | ahuimanu
# Processing Record 25 of Set 15 | kalach-na-donu
# Processing Record 26 of Set 15 | katete
# Processing Record 27 of Set 15 | tooele
# Processing Record 28 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 15 | hirara
# Processing Record 30 of Set 15 | linxia
# Processing Record 31 of Set 15 | guiratinga
# Processing Record 32 of Set 15 | nagua
# Processing Record 33 of Set 15 | pangai
# Processing Record 34 of Set 15 | sabla
# Processing Record 35 of Set 15 | charters towers
# Processing Record 36 of Set 15 | christchurch
# Processing Record 37 of Set 15 | sellye
# Processing Record 38 of Set 15 | preobrazheniye
# Processing Record 39 of Set 15 | santa vitoria do palmar
# Processing Record 40 of Set 15 | esna
# Processing Record 41 of Set 15 | lujan
# Processing Record 42 of Set 15 | patharia
# Processing Record 43 of Set 15 | tarata
# Processing Record 44 of Set 15 | wagar
# Processing Record 45 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 15 | zakupne
# Processing Record 47 of Set 15 | swan river
# Processing Record 48 of Set 15 | mafinga
# Processing Record 49 of Set 15 | totness
# Processing Record 50 of Set 15 | mandalgovi
# Processing Record 1 of Set 16 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 16 | ostrovnoy
# Processing Record 4 of Set 16 | peniche
# Processing Record 5 of Set 16 | mehamn
# Processing Record 6 of Set 16 | krasnoye
# Processing Record 7 of Set 16 | verkhoturye
# Processing Record 8 of Set 16 | algeciras
# Processing Record 9 of Set 16 | rajula
# Processing Record 10 of Set 16 | elk point
# Processing Record 11 of Set 16 | hvide sande
# Processing Record 12 of Set 16 | repnoye
# Processing Record 13 of Set 16 | mahibadhoo
# Processing Record 14 of Set 16 | bucerias
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather_df = pd.DataFrame(city_data)
city_weather_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Talnakh  69.4865   88.3972      4.21        92          40
# 1          Bluff -46.6000  168.3333     60.64        84          20
# 2         Beloha -25.1667   45.0500     79.05        49           2
# 3       Klaksvik  62.2266   -6.5890     45.52        92          79
# 4     Nanortalik  60.1432  -45.2371     11.25        73           0
# ..           ...      ...       ...       ...       ...         ...
# 701    Elk Point  42.6833  -96.6836     64.24        33         100
# 702  Hvide Sande  56.0045    8.1294     41.09        81          75
# 703      Repnoye  51.5921   43.1861     33.40       100          40
# 704   Mahibadhoo   3.7833   72.9667     83.73        64           3
# 705     Bucerias  20.7500 -105.3333     67.98        80          94
#
#      Wind Speed Country Current Description
# 0          5.73      RU    scattered clouds
# 1         14.74      NZ          few clouds
# 2         15.52      MG           clear sky
# 3         20.00      FO       broken clouds
# 4          6.17      GL           clear sky
# ..          ...     ...                 ...
# 701       18.16      US     overcast clouds
# 702       12.66      DK          light rain
# 703       11.41      RU    scattered clouds
# 704       14.79      MV           clear sky
# 705        3.18      MX     overcast clouds
#
# [706 rows x 9 columns]

# %%
#Arrange the order of the columns
new_column_order =['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Current Description']
city_weather_df = city_weather_df[new_column_order]
city_weather_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Talnakh      RU  69.4865   88.3972      4.21        92          40
# 1          Bluff      NZ -46.6000  168.3333     60.64        84          20
# 2         Beloha      MG -25.1667   45.0500     79.05        49           2
# 3       Klaksvik      FO  62.2266   -6.5890     45.52        92          79
# 4     Nanortalik      GL  60.1432  -45.2371     11.25        73           0
# ..           ...     ...      ...       ...       ...       ...         ...
# 701    Elk Point      US  42.6833  -96.6836     64.24        33         100
# 702  Hvide Sande      DK  56.0045    8.1294     41.09        81          75
# 703      Repnoye      RU  51.5921   43.1861     33.40       100          40
# 704   Mahibadhoo      MV   3.7833   72.9667     83.73        64           3
# 705     Bucerias      MX  20.7500 -105.3333     67.98        80          94
#
#      Wind Speed Current Description
# 0          5.73    scattered clouds
# 1         14.74          few clouds
# 2         15.52           clear sky
# 3         20.00       broken clouds
# 4          6.17           clear sky
# ..          ...                 ...
# 701       18.16     overcast clouds
# 702       12.66          light rain
# 703       11.41    scattered clouds
# 704       14.79           clear sky
# 705        3.18     overcast clouds
#
# [706 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_weather_df.to_csv(output_data_file, index_label="City_ID")
